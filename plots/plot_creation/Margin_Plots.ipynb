# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as plticker

# %%
tex_fonts = {
    "text.usetex": True,
    "font.family": "serif",
    "font.sans-serif": ["Palatino"],
    "axes.labelsize": 12,
    "font.size": 12,
    "legend.fontsize": 10,
    "xtick.labelsize": 11,
    "ytick.labelsize": 11
}

plt.rcParams.update(tex_fonts)

# %%
def set_size(width_pt, fraction=1, subplots=(1, 1)):

    # Width of figure (in pts)
    fig_width_pt = width_pt * fraction
    # Convert from pt to inches
    inches_per_pt = 1 / 72.27

    # Golden ratio to set aesthetic figure height
    golden_ratio = (5**.5 - 1) / 2

    # Figure width in inches
    fig_width_in = fig_width_pt * inches_per_pt
    # Figure height in inches
    fig_height_in = fig_width_in * golden_ratio * (subplots[0] / subplots[1])

    return (fig_width_in, fig_height_in)

# %%
wue_IS_100_ = pd.read_hdf("results/Wue_IS100/wue_IS_100_merged.h5", "wue_IS_100")
wue_IS_50_ =  pd.read_hdf("results/Wue_IS50/wue_IS_50_merged.h5", "wue_IS50")
wue_IS_25_ =  pd.read_hdf("results/Wue_IS25/wue_IS_25_merged.h5", "wue_IS_25")
wue_IS_150_ = pd.read_hdf("results/Wue_IS150/wue_IS_150_merged.h5", "wue_IS150")
df_list_ = [wue_IS_25_, wue_IS_50_, wue_IS_100_, wue_IS_150_]
wue_IS = pd.concat(df_list_, ignore_index=True)
wue_IS
# Out:
#     Customers_N   Distance      Time       Stops  Stops_h  FixedDC_Cost  \
# 0            25   55999.00  12285.00   26.000000      7.6         240.0
# 1            25   73648.00  14948.00   26.000000      6.3         240.0
# 2            25   67743.00  13700.00   26.000000      6.8         240.0
# 3            25   69236.00  13363.00   26.000000      7.0         240.0
# 4            25   64347.00  13266.00   26.000000      7.1         240.0
# 5            25   60236.00  12335.00   26.000000      7.6         240.0
# 6            25   68631.00  13848.00   26.000000      6.8         240.0
# 7            25   72695.00  13400.00   26.000000      7.0         240.0
# 8            25   59417.00  12430.00   26.000000      7.5         240.0
# 9            25   49619.00  11554.00   26.000000      8.1         240.0
# 10           50   83574.00  20838.00   52.000000      9.0         240.0
# 11           50   93517.00  23345.00   52.000000      8.0         240.0
# ...

# %%
w100 = wue_IS[wue_IS["Customers_N"] == 100]
w100
# Out:
#     Customers_N  Distance     Time  Stops  Stops_h  FixedDC_Cost  Trans_Cost  \
# 20          100  151488.0  40183.0  103.0      9.2         480.0      220.75
# 21          100  155459.0  40481.0  103.0      9.2         480.0      222.90
# 22          100  158247.0  40461.0  103.0      9.2         480.0      223.30
# 23          100  148229.0  40572.0  103.0      9.1         480.0      222.03
# 24          100  165432.0  42106.0  103.0      8.8         480.0      232.52
# 25          100  146739.0  40315.0  103.0      9.2         480.0      220.53
# 26          100  164382.0  41628.0  103.0      8.9         480.0      230.03
# 27          100  161345.0  41199.0  103.0      9.0         480.0      227.41
# 28          100  148652.0  39887.0  103.0      9.3         480.0      218.82
# 29          100  145619.0  40546.0  103.0      9.1         480.0      221.44
#
#     Variable_DC  Fixed_V  Total_Cost  Var_per_order  Trans_per_order  \
# ...

# %%
w100.mean()
# Out:
# C:\Users\michi\AppData\Local\Temp/ipykernel_67988/1154208828.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   w100.mean()
# Customers_N                100.000
# Distance                154559.200
# Time                     40737.800
# Stops                      103.000
# Stops_h                      9.100
# FixedDC_Cost               480.000
# Trans_Cost                 223.973
# Variable_DC               1208.517
# Fixed_V                     67.500
# Total_Cost                1979.990
# Var_per_order               12.085
# Trans_per_order              2.240
# Transp_order_with_V          2.915
# FixedDC_per_order            4.800
# Total_Cost_per_order        19.799
# Items                     4543.300
# Cost_per_item                0.437
# dtype: float64

# %%
def basket_prof_IS(x):
    basket_size = (x/x) * 100
    COGS = 80
    Delivery_inc = (4/x)*100
    cost_order = (19.799/x)*100
    basket_prof = (basket_size - COGS - cost_order + Delivery_inc)
    
    return(basket_prof)

# %%
basket_prof(125)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_58284/2642260205.py in <module>
# ----> 1 basket_prof(125)
#
# NameError: name 'basket_prof' is not defined

# %%
basket_profs_IS= [basket_prof_IS(x) for x in range(50,161)]

# %%
basket_sizes = list(range(50,161))

# %%
wue_D_100 =  pd.read_hdf("results/Wue_D100/wue_D_100_merged.h5", "wue_D_100")
wue_D_avg = wue_D_100.mean()
wue_D_avg
# Out:
# C:\Users\michi\AppData\Local\Temp/ipykernel_58284/4244243297.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   wue_D_avg = wue_D_100.mean()
# Customers_N                100.000
# Distance                213952.400
# Time                     44029.600
# Stops                      103.300
# Stops_h                      8.460
# FixedDC_Cost               480.000
# Trans_Cost                 250.512
# Variable_DC                662.270
# Fixed_V                     74.250
# Total_Cost                1467.032
# Var_per_order                6.622
# Trans_per_order              2.506
# Transp_order_with_V          3.248
# FixedDC_per_order            4.800
# Total_Cost_per_order        14.670
# Items                     4536.100
# Cost_per_item                0.325
# dtype: float64

# %%
def basket_prof_D(x):
    basket_size = (x/x) * 100
    COGS = 80
    Delivery_inc = (4/x)*100
    cost_order = (14.67/x)*100
    basket_prof = (basket_size - COGS -cost_order + Delivery_inc)
    
    return(basket_prof)

# %%
basket_profs_D= [basket_prof_D(x) for x in range(50,161)]

# %%
wue_F =  pd.read_hdf("wue_F_merged.h5", "wue_F")
w100F = wue_F[wue_F["Customers_N"] == 100]
w100F
wue_F_avg = w100F.mean()
wue_F_avg
# Out:
# C:\Users\michi\AppData\Local\Temp/ipykernel_58284/325544882.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   wue_F_avg = w100F.mean()
# Customers_N                100.000
# Distance                215431.400
# Time                     43515.200
# Stops                      103.400
# Stops_h                      8.560
# FixedDC_Cost               560.000
# Trans_Cost                 248.303
# Variable_DC                390.104
# Fixed_V                     76.500
# Total_Cost                1274.907
# Var_per_order                3.901
# Trans_per_order              2.483
# Transp_order_with_V          3.249
# FixedDC_per_order            5.600
# Total_Cost_per_order        12.750
# Items                     4536.100
# Cost_per_item                0.282
# dtype: float64

# %%
def basket_prof_F(x):
    basket_size = (x/x) * 100
    COGS = 80
    Delivery_inc = (4/x)*100

    cost_order = (12.75/x)*100
    basket_prof = (basket_size - COGS - cost_order + Delivery_inc)
    
    return(basket_prof)
basket_profs_F= [basket_prof_F(x) for x in range(50,161)]

# %%
alb_IS_100 = pd.read_hdf("results/Alb_IS100/alb_IS_100_merged.h5", "alb_IS_100")
alb_D_100 =  pd.read_hdf("results/Alb_D100/alb_D_100_merged.h5", "alb_D_100")
alb_F=  pd.read_hdf("alb_F_merged.h5", "alb_F")
alb_F_100 = alb_F[alb_F["Customers_N"] == 100]

# %%
alb_IS_100["Total_Cost_per_order"].mean()
# Out:
# 19.533

# %%
def basket_prof_alb_IS(x):
    basket_size = (x/x) * 100
    COGS = 80
    Delivery_inc = (4/x)*100

    cost_order = (19.533/x)*100
    basket_prof = (basket_size - COGS - cost_order + Delivery_inc)
    
    return(basket_prof)

# %%
basket_profs_alb_IS= [basket_prof_alb_IS(x) for x in range(50,161)]

# %%
alb_D_100["Total_Cost_per_order"].mean()
# Out:
# 14.196000000000002

# %%
def basket_prof_alb_D(x):
    basket_size = (x/x) * 100
    COGS = 80
    Delivery_inc = (4/x)*100
    cost_order = (14.2/x)*100
    basket_prof = (basket_size - COGS  - cost_order + Delivery_inc)
    
    return(basket_prof)
basket_profs_alb_D= [basket_prof_alb_D(x) for x in range(50,161)]

# %%
alb_F_100["Total_Cost_per_order"].mean()
# Out:
# 12.487

# %%
def basket_prof_alb_F(x):
    basket_size = (x/x) * 100
    COGS = 80
    Delivery_inc = (4/x)*100
    cost_order = (12.49/x)*100
    basket_prof = (basket_size - COGS - cost_order + Delivery_inc)
    
    return(basket_prof)
basket_profs_alb_F= [basket_prof_alb_F(x) for x in range(50,161)]

# %%
basket_prof_alb_IS(80)
# Out:
# 0.5837499999999984

# %%
basket_prof_alb_D(80)
# Out:
# 7.25

# %%
basket_prof_alb_F(80)
# Out:
# 9.3875

# %%
basket_prof_IS(80)
# Out:
# 0.25124999999999886

# %%
basket_prof_D(80)
# Out:
# 6.662499999999998

# %%
basket_prof_F(80)
# Out:
# 9.062500000000002

# %%
from matplotlib.lines import Line2D
custom_line = [Line2D([0], [0], color="grey", lw=1.3, ls = "--")]
plt.style.use("seaborn-ticks")

fig, (ax1,ax2) = plt.subplots(1,2, figsize=set_size(480))

ax1.set_title("\\textbf{Albstadt}", fontsize=14)
ax2.set_title("\\textbf{Würzburg}", fontsize=14)
ax1.set_ylabel("\\textbf{Margin \%}")
fig.supxlabel("\\textbf{Basket size €}", y = 0.05, fontsize=12)

ax1.plot(basket_sizes,basket_profs_alb_IS,  label="In Store", color="#207720")
ax1.plot(basket_sizes, basket_profs_alb_D, label = "Darkstore", color="#234990")
ax1.plot(basket_sizes, basket_profs_alb_F, label= "FC", color = "#E23726")
ax1.yaxis.grid(True)

ax2.plot(basket_sizes, basket_profs_IS,  label="In Store", color="#207720")
ax2.plot(basket_sizes, basket_profs_D, label = "Darkstore", color="#234990")
ax2.plot(basket_sizes, basket_profs_F, label= "FC", color = "#E23726")
ax2.yaxis.grid(True)

ax1.set_yticks([-10, -7.5, -5,-2.5, 0,2.5, 5,7.5 , 10, 12.5, 15],["$-10\%$",  "$-7.5\%$","$-5\%$", "$-2.5\%$", 
                                                                 "$0\%$", "$2.5\%$", "$5\%$",
                                                                  "$7.5\%$","$10\%$", "$12.5\%$", "$15\%$"], rotation=0)
ax2.set_yticks([-10, -7.5, -5,-2.5, 0,2.5, 5,7.5 , 10, 12.5, 15],["$-10\%$",  "$-7.5\%$","$-5\%$", "$-2.5\%$", 
                                                                 "$0\%$", "$2.5\%$", "$5\%$",
                                                                  "$7.5\%$","$10\%$", "$12.5\%$", "$15\%$"], rotation=0)
loc =plticker.MultipleLocator(base=20)
ax1.xaxis.set_major_locator(loc)


loc =plticker.MultipleLocator(base=20)
ax2.xaxis.set_major_locator(loc)

ax1.axhline(y=0,xmin=0,xmax=160,c="black",linewidth=1.3,zorder=0)
ax2.axhline(y=0,xmin=0,xmax=160,c="black",linewidth=1.3,zorder=0)


ax1.set_ylim(ymax = 16, ymin =-12.5)
ax2.set_ylim(ymax=16, ymin=-12.5)

ax1.set_xlim(xmax = 164, xmin =46)
ax2.set_xlim(xmax=164, xmin=46)

ax1.vlines(x=80,ymin=-12.5,ymax=0.583749,colors="grey",linewidth=1.3,zorder=0, ls="--")
ax1.hlines(y=0.583749,xmin=46,xmax=80,colors="grey",linewidth=1.3,zorder=0, ls="--")

ax1.vlines(x=80,ymin=-12.5,ymax=7.25,colors="grey",linewidth=1.3,zorder=0, ls="--")
ax1.hlines(y=7.25,xmin=46,xmax=80,colors="grey",linewidth=1.3,zorder=0, ls="--")

ax1.vlines(x=80,ymin=-12.5,ymax=9.3875,colors="grey",linewidth=1.3,zorder=0, ls="--")
ax1.hlines(y=9.3875,xmin=46,xmax=80,colors="grey",linewidth=1.3,zorder=0, ls="--")

ax2.vlines(x=80,ymin=-12.5,ymax=0.251249,colors="grey",linewidth=1.3,zorder=0, ls="--")
ax2.hlines(y=0.251249,xmin=46,xmax=80,colors="grey",linewidth=1.3,zorder=0, ls="--")

ax2.vlines(x=80,ymin=-12.5,ymax=6.66249,colors="grey",linewidth=1.3,zorder=0, ls="--")
ax2.hlines(y=6.66249,xmin=46,xmax=80,colors="grey",linewidth=1.3,zorder=0, ls="--")

ax2.vlines(x=80,ymin=-12.5,ymax=9.0625,colors="grey",linewidth=1.3,zorder=0, ls="--")
ax2.hlines(y=9.0625,xmin=46,xmax=80,colors="grey",linewidth=1.3,zorder=0, ls="--")



fig.legend(custom_line, ['Assumed Base Basket Size'], loc= "lower right", labelspacing=0.2,
         prop={"size":"small"})

handles, labels = ax1.get_legend_handles_labels()
fig.legend(handles, labels, loc='lower left', frameon=True,
           fancybox=True, ncol=1, borderpad=0.1, labelspacing = 0.2, borderaxespad=0.1)

fig.tight_layout()
plt.show()
fig.savefig("result_graph/basket_prof2.svg", format="svg")

# %%
from matplotlib.lines import Line2D
custom_line = [Line2D([0], [0], color="grey", lw=1.3, ls = "--")]
plt.style.use("seaborn-ticks")

fig, (ax1,ax2) = plt.subplots(1,2, figsize=set_size(480))

ax1.set_title("\\textbf{Albstadt}", fontsize=14)
ax2.set_title("\\textbf{Würzburg}", fontsize=14)
ax1.set_ylabel("\\textbf{Margin \%}")
fig.supxlabel("\\textbf{Basket size €}", y = 0.05, fontsize=12)

ax1.plot(basket_sizes,basket_profs_alb_IS,  label="In Store", color="#207720")
ax1.plot(basket_sizes, basket_profs_alb_D, label = "Darkstore", color="#234990")
ax1.plot(basket_sizes, basket_profs_alb_F, label= "FC", color = "#E23726")
ax1.yaxis.grid(True)

ax2.plot(basket_sizes, basket_profs_IS,  label="In Store", color="#207720")
ax2.plot(basket_sizes, basket_profs_D, label = "Darkstore", color="#234990")
ax2.plot(basket_sizes, basket_profs_F, label= "FC", color = "#E23726")
ax2.yaxis.grid(True)

ax1.set_yticks([-10, -7.5, -5,-2.5, 0,2.5, 5,7.5 , 10, 12.5, 15],["$-10\%$",  "$-7.5\%$","$-5\%$", "$-2.5\%$", 
                                                                 "$0\%$", "$2.5\%$", "$5\%$",
                                                                  "$7.5\%$","$10\%$", "$12.5\%$", "$15\%$"], rotation=0)
ax2.set_yticks([-10, -7.5, -5,-2.5, 0,2.5, 5,7.5 , 10, 12.5, 15],["$-10\%$",  "$-7.5\%$","$-5\%$", "$-2.5\%$", 
                                                                 "$0\%$", "$2.5\%$", "$5\%$",
                                                                  "$7.5\%$","$10\%$", "$12.5\%$", "$15\%$"], rotation=0)
loc =plticker.MultipleLocator(base=20)
ax1.xaxis.set_major_locator(loc)


loc =plticker.MultipleLocator(base=20)
ax2.xaxis.set_major_locator(loc)

ax1.axhline(y=0,xmin=0,xmax=160,c="black",linewidth=1.3,zorder=0)
ax2.axhline(y=0,xmin=0,xmax=160,c="black",linewidth=1.3,zorder=0)


ax1.set_ylim(ymax = 16, ymin =-12.5)
ax2.set_ylim(ymax=16, ymin=-12.5)

ax1.set_xlim(xmax = 164, xmin =46)
ax2.set_xlim(xmax=164, xmin=46)

ax1.vlines(x=80,ymin=-12.5,ymax=0.583749,colors="#207720",linewidth=1.3,zorder=0, ls="--")
ax1.hlines(y=0.583749,xmin=46,xmax=80,colors="#207720",linewidth=1.3,zorder=0, ls="--")

ax1.vlines(x=80,ymin=-12.5,ymax=7.25,colors="grey",linewidth=1.3,zorder=0, ls="--")
ax1.hlines(y=7.25,xmin=46,xmax=80,colors="#234990",linewidth=1.3,zorder=0, ls="--")

ax1.vlines(x=80,ymin=-12.5,ymax=9.3875,colors="grey",linewidth=1.3,zorder=0, ls="--")
ax1.hlines(y=9.3875,xmin=46,xmax=80,colors="#E23726",linewidth=1.3,zorder=0, ls="--")

ax2.vlines(x=80,ymin=-12.5,ymax=0.251249,colors="grey",linewidth=1.3,zorder=0, ls="--")
ax2.hlines(y=0.251249,xmin=46,xmax=80,colors="grey",linewidth=1.3,zorder=0, ls="--")

ax2.vlines(x=80,ymin=-12.5,ymax=6.66249,colors="grey",linewidth=1.3,zorder=0, ls="--")
ax2.hlines(y=6.66249,xmin=46,xmax=80,colors="grey",linewidth=1.3,zorder=0, ls="--")

ax2.vlines(x=80,ymin=-12.5,ymax=9.0625,colors="grey",linewidth=1.3,zorder=0, ls="--")
ax2.hlines(y=9.0625,xmin=46,xmax=80,colors="grey",linewidth=1.3,zorder=0, ls="--")



fig.legend(custom_line, ['Assumed Base Basket Size'], loc= "lower right", labelspacing=0.2,
         prop={"size":"small"})

handles, labels = ax1.get_legend_handles_labels()
fig.legend(handles, labels, loc='lower left', frameon=True,
           fancybox=True, ncol=1, borderpad=0.1, labelspacing = 0.2, borderaxespad=0.1)

fig.tight_layout()
plt.show()
#fig.savefig("result_graph/basket_prof.svg", format="svg")

# %%
wue_F_25_ = pd.read_hdf("results/Wue_F25/wue_F_25_merged.h5", "wue_F_25")
wue_F_50_ =  pd.read_hdf("results/Wue_F50/wue_F_50_merged.h5", "wue_F_50")
wue_F_100_ =  pd.read_hdf("results/Wue_F100/wue_F_100_merged.h5", "wue_F_100")
wue_F_150_ = pd.read_hdf("results/Wue_F150/wue_F_150_merged.h5", "wue_F_150")
df_list_ = [wue_F_25_, wue_F_50_, wue_F_100_, wue_F_150_]
wue_F = pd.concat(df_list_, ignore_index=True)
wue_F["FixedDC_Cost"] = 560
wue_F["Total_Cost_per_order"] = ((wue_F["FixedDC_Cost"] + wue_F["Trans_Cost"] + wue_F["Variable_DC"]+
                                 wue_F["Fixed_V"])/wue_F["Customers_N"]).round(2)
wue_F["Total_Cost"] = (wue_F["FixedDC_Cost"] + wue_F["Trans_Cost"] + wue_F["Variable_DC"]+
                                 wue_F["Fixed_V"]).round(2)
wue_F["Cost_per_item"] = (wue_F["Total_Cost"] / wue_F["Items"]).round(2)
wue_F["FixedDC_per_order"] = (wue_F["FixedDC_Cost"] / wue_F["Customers_N"]).round(2)
wue_F.to_hdf("wue_F_merged.h5", mode = "w", key = "wue_F")
wue_F

# %%
alb_F_25_ = pd.read_hdf("results/alb_F25/alb_F_25_merged.h5", "alb_F_25")
alb_F_50_ =  pd.read_hdf("results/alb_F50/alb_F_50_merged.h5", "alb_F_50")
alb_F_100_ =  pd.read_hdf("results/alb_F100/alb_F_100_merged.h5", "alb_F_100")
alb_F_150_ = pd.read_hdf("results/alb_F150/alb_F_150_merged.h5", "alb_F_150")
df_list_ = [alb_F_25_, alb_F_50_, alb_F_100_, alb_F_150_]
alb_F = pd.concat(df_list_, ignore_index=True)
alb_F["FixedDC_Cost"] = 560
alb_F["Total_Cost_per_order"] = ((alb_F["FixedDC_Cost"] + alb_F["Trans_Cost"] + alb_F["Variable_DC"]+
                                 alb_F["Fixed_V"])/alb_F["Customers_N"]).round(2)
alb_F["Total_Cost"] = (alb_F["FixedDC_Cost"] + alb_F["Trans_Cost"] + alb_F["Variable_DC"]+
                                 alb_F["Fixed_V"]).round(2)
alb_F["Cost_per_item"] = (alb_F["Total_Cost"] / alb_F["Items"]).round(2)
alb_F["FixedDC_per_order"] = (alb_F["FixedDC_Cost"] / alb_F["Customers_N"]).round(2)
alb_F.to_hdf("alb_F_merged.h5", mode = "w", key = "alb_F")
alb_F

# %%
alb_F_100
# Out:
#     Customers_N   Distance      Time       Stops  Stops_h  FixedDC_Cost  \
# 20          100  143108.00  37456.00  103.000000      9.9           560
# 21          100  155763.87  38270.97  102.999928      9.7           560
# 22          100  159333.00  38827.00  104.000000      9.6           560
# 23          100  175066.00  40188.00  104.000000      9.3           560
# 24          100  143774.00  36896.00  103.000000     10.0           560
# 25          100  170925.00  39032.00  104.000000      9.6           560
# 26          100  176251.00  40054.00  104.000000      9.3           560
# 27          100  195801.00  40952.00  104.000000      9.1           560
# 28          100  160514.00  39207.00  104.000000      9.5           560
# 29          100  171211.99  39180.00  102.999999      9.5           560
#
#     Trans_Cost  Variable_DC    Fixed_V  Total_Cost  Var_per_order  \
# 20      206.11       391.90  67.500000     1225.51           3.92
# ...

# %%
alb_F_100.mean()
# Out:
# C:\Users\michi\AppData\Local\Temp/ipykernel_67988/2725827810.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   alb_F_100.mean()
# Customers_N                100.000000
# Distance                165174.786000
# Time                     39006.297000
# Stops                      103.599993
# Stops_h                      9.550000
# FixedDC_Cost               560.000000
# Trans_Cost                 217.546000
# Variable_DC                390.104000
# Fixed_V                     80.999992
# Total_Cost                1248.650000
# Var_per_order                3.901000
# Trans_per_order              2.176000
# Transp_order_with_V          2.987000
# FixedDC_per_order            5.600000
# Total_Cost_per_order        12.487000
# Items                     4536.100000
# Cost_per_item                0.275000
# ...

# %%
var_factors_F = [x / 1000.0 for x in range(76, 110 ,2)]
len(var_factors_F)
# Out:
# 17

# %%
def prof_picking_alb_F(var_factor):
    Customers = 100
    Items = 4536
    basket_size = (100/100) * 100
    COGS = 80
    Delivery_inc = (5/100)*100
    marketing = (2/100)*100
    cost_order_manipulation =  ((var_factor*Items)/Customers) + 2.987 + 5.6  
    cost_order = (cost_order_manipulation/100)*100
    prof_picking = (basket_size - COGS - marketing - cost_order + Delivery_inc)
    
    return(prof_picking)

# %%
prof_picking_alb_F(0.5)
# Out:
# -8.267

# %%
prof_picking_alb_F_list= [prof_picking_alb_F(var_factor) for var_factor in var_factors_F]
prof_picking_alb_F_list
# Out:
# [10.96564,
#  10.87492,
#  10.7842,
#  10.693480000000001,
#  10.60276,
#  10.51204,
#  10.421320000000001,
#  10.3306,
#  10.23988,
#  10.14916,
#  10.058440000000001,
#  9.967720000000002,
#  9.876999999999999,
#  9.786280000000001,
#  9.695559999999999,
#  9.60484,
#  9.51412]

# %%
prof_picking_alb_F_list.reverse()

# %%
len(prof_picking_alb_F_list)
# Out:
# 17

# %%
F_picking_amount = [x / 100.0 for x in range(20000, 40000 ,1240)]
F_picking_amount
# Out:
# [200.0,
#  212.4,
#  224.8,
#  237.2,
#  249.6,
#  262.0,
#  274.4,
#  286.8,
#  299.2,
#  311.6,
#  324.0,
#  336.4,
#  348.8,
#  361.2,
#  373.6,
#  386.0,
#  398.4]

# %%
len(F_picking_amount)
# Out:
# 17

# %%
plt.style.use("seaborn-ticks")

fig, ax1 = plt.subplots(1,1, figsize=set_size(445))

ax1.plot(F_picking_amount, prof_picking_alb_F_list)
#ax1.plot(F_picking_amount, basket_profs_D)
#ax1.plot(F_picking_amount, basket_profs_F)
fig.tight_layout()
plt.show()

# %%
wue_F=  pd.read_hdf("wue_F_merged.h5", "wue_F")
wue_F100 = wue_F[wue_F["Customers_N"] == 100]
wue_F100
# Out:
#     Customers_N  Distance     Time  Stops  Stops_h  FixedDC_Cost  Trans_Cost  \
# 20          100  239403.0  44034.0  104.0      8.5           560      255.11
# 21          100  214327.0  43512.0  103.0      8.5           560      248.09
# 22          100  212442.0  43108.0  103.0      8.6           560      245.81
# 23          100  203943.0  43469.0  103.0      8.5           560      246.01
# 24          100  208490.0  43539.0  103.0      8.5           560      247.17
# 25          100  205840.0  42688.0  103.0      8.7           560      242.59
# 26          100  198211.0  43724.0  103.0      8.5           560      246.21
# 27          100  229096.0  44204.0  104.0      8.5           560      254.08
# 28          100  219447.0  43142.0  104.0      8.7           560      247.23
# 29          100  223115.0  43732.0  104.0      8.6           560      250.73
#
#     Variable_DC  Fixed_V  Total_Cost  Var_per_order  Trans_per_order  \
# ...

# %%
wue_F100.mean()
# Out:
# C:\Users\michi\AppData\Local\Temp/ipykernel_67988/1496103524.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   wue_F100.mean()
# Customers_N                100.000
# Distance                215431.400
# Time                     43515.200
# Stops                      103.400
# Stops_h                      8.560
# FixedDC_Cost               560.000
# Trans_Cost                 248.303
# Variable_DC                390.104
# Fixed_V                     76.500
# Total_Cost                1274.907
# Var_per_order                3.901
# Trans_per_order              2.483
# Transp_order_with_V          3.249
# FixedDC_per_order            5.600
# Total_Cost_per_order        12.750
# Items                     4536.100
# Cost_per_item                0.282
# dtype: float64

# %%
def prof_picking_wue_F(var_factor):
    Customers = 100
    Items = 4536
    basket_size = (100/100) * 100
    COGS = 80
    Delivery_inc = (5/100)*100
    marketing = (2/100)*100
    cost_order_manipulation =  ((var_factor*Items)/Customers) + 3.249 + 5.6  
    cost_order = (cost_order_manipulation/100)*100
    prof_picking = (basket_size - COGS - marketing - cost_order + Delivery_inc)
    
    return(prof_picking)

# %%
prof_picking_wue_F(0.00001)
# Out:
# 14.1505464

# %%
prof_picking_wue_F_list= [prof_picking_wue_F(var_factor) for var_factor in var_factors_F]
prof_picking_wue_F_list.reverse()
prof_picking_wue_F_list
# Out:
# [9.252119999999998,
#  9.34284,
#  9.433560000000002,
#  9.524280000000001,
#  9.615,
#  9.70572,
#  9.79644,
#  9.88716,
#  9.977880000000003,
#  10.068599999999998,
#  10.159320000000001,
#  10.25004,
#  10.340760000000001,
#  10.43148,
#  10.5222,
#  10.61292,
#  10.70364]

# %%
plt.style.use("seaborn-ticks")

fig, ax1 = plt.subplots(1,1, figsize=set_size(445))

ax1.plot(F_picking_amount, prof_picking_alb_F_list)
ax1.plot(F_picking_amount, prof_picking_wue_F_list)
#ax1.plot(F_picking_amount, basket_profs_F)
fig.tight_layout()
plt.show()

# %%
w100
# Out:
#     Customers_N  Distance     Time  Stops  Stops_h  FixedDC_Cost  Trans_Cost  \
# 20          100  151488.0  40183.0  103.0      9.2         480.0      220.75
# 21          100  155459.0  40481.0  103.0      9.2         480.0      222.90
# 22          100  158247.0  40461.0  103.0      9.2         480.0      223.30
# 23          100  148229.0  40572.0  103.0      9.1         480.0      222.03
# 24          100  165432.0  42106.0  103.0      8.8         480.0      232.52
# 25          100  146739.0  40315.0  103.0      9.2         480.0      220.53
# 26          100  164382.0  41628.0  103.0      8.9         480.0      230.03
# 27          100  161345.0  41199.0  103.0      9.0         480.0      227.41
# 28          100  148652.0  39887.0  103.0      9.3         480.0      218.82
# 29          100  145619.0  40546.0  103.0      9.1         480.0      221.44
#
#     Variable_DC  Fixed_V  Total_Cost  Var_per_order  Trans_per_order  \
# ...

# %%
[x / 1000.0 for x in range(112, 409 ,2)]

# %%
var_factors_IS = [x / 1000.0 for x in range(112, 409 ,20)]

# %%
var_factors_IS
# Out:
# [0.112,
#  0.132,
#  0.152,
#  0.172,
#  0.192,
#  0.212,
#  0.232,
#  0.252,
#  0.272,
#  0.292,
#  0.312,
#  0.332,
#  0.352,
#  0.372,
#  0.392]

# %%
w100.mean()
# Out:
# C:\Users\michi\AppData\Local\Temp/ipykernel_67988/1154208828.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   w100.mean()
# Customers_N                100.000
# Distance                154559.200
# Time                     40737.800
# Stops                      103.000
# Stops_h                      9.100
# FixedDC_Cost               480.000
# Trans_Cost                 223.973
# Variable_DC               1208.517
# Fixed_V                     67.500
# Total_Cost                1979.990
# Var_per_order               12.085
# Trans_per_order              2.240
# Transp_order_with_V          2.915
# FixedDC_per_order            4.800
# Total_Cost_per_order        19.799
# Items                     4543.300
# Cost_per_item                0.437
# dtype: float64

# %%
def prof_picking_wue_IS(var_factor):
    Customers = 100
    Items = 4543
    basket_size = (100/100) * 100
    COGS = 80
    Delivery_inc = (5/100)*100
    marketing = (2/100)*100
    cost_order_manipulation =  ((var_factor*Items)/Customers) + 2.915 +4.8  
    cost_order = (cost_order_manipulation/100)*100
    prof_picking = (basket_size - COGS - marketing - cost_order + Delivery_inc)
    
    return(prof_picking)

# %%
wue_IS_pick= [prof_picking_wue_IS(var_factor) for var_factor in var_factors_IS]
wue_IS_pick.reverse()
wue_IS_pick
# Out:
# [-2.52356,
#  -1.61496,
#  -0.7063600000000001,
#  0.20223999999999975,
#  1.1108399999999996,
#  2.0194399999999995,
#  2.9280399999999993,
#  3.836639999999999,
#  4.745239999999999,
#  5.653839999999999,
#  6.562439999999999,
#  7.471039999999997,
#  8.379640000000002,
#  9.28824,
#  10.196839999999998]

# %%
len(wue_IS_pick)
# Out:
# 15

# %%
IS_picking_amount = [x / 100.0 for x in range(4000, 20200 ,1140)]
IS_picking_amount
# Out:
# [40.0,
#  51.4,
#  62.8,
#  74.2,
#  85.6,
#  97.0,
#  108.4,
#  119.8,
#  131.2,
#  142.6,
#  154.0,
#  165.4,
#  176.8,
#  188.2,
#  199.6]

# %%
len(IS_picking_amount)
# Out:
# 15

# %%
plt.style.use("seaborn-ticks")

fig, (ax1,ax2) = plt.subplots(1,2, figsize=set_size(445))

ax1.plot(F_picking_amount, prof_picking_alb_F_list)
ax2.plot(F_picking_amount, prof_picking_wue_F_list)
ax2.plot(IS_picking_amount, wue_IS_pick)
#ax1.plot(F_picking_amount, basket_profs_F)
fig.tight_layout()
plt.show()

# %%
wue_D_100
# Out:
#     Customers_N  Distance     Time       Stops  Stops_h  FixedDC_Cost  \
# 1           100  197025.0  42184.0  103.000000      8.8         480.0
# 2           100  207631.0  44069.0  103.000000      8.4         480.0
# 3           100  204972.0  42511.0  102.999998      8.7         480.0
# 4           100  195724.0  42660.0  104.000000      8.8         480.0
# 5           100  231491.0  45191.0  104.000000      8.3         480.0
# 6           100  213050.0  43193.0  104.000000      8.7         480.0
# 7           100  193233.0  42553.0  103.000000      8.7         480.0
# 8           100  248809.0  47231.0  103.000000      7.9         480.0
# 9           100  218236.0  44409.0  103.000000      8.3         480.0
# 10          100  229353.0  46295.0  103.000000      8.0         480.0
#
#     Trans_Cost  Variable_DC  Fixed_V  Total_Cost  Var_per_order  \
# 1       238.58       665.32     67.5     1451.40           6.65
# 2       249.56       639.33     67.5     1436.39           6.39
# ...

# %%
var_factors_D = [x / 10000.0 for x in range(860, 1760 ,69)]

# %%
len(var_factors_D)
# Out:
# 14

# %%
var_factors_D
# Out:
# [0.086,
#  0.0929,
#  0.0998,
#  0.1067,
#  0.1136,
#  0.1205,
#  0.1274,
#  0.1343,
#  0.1412,
#  0.1481,
#  0.155,
#  0.1619,
#  0.1688,
#  0.1757]

# %%
wue_D_100.mean()
# Out:
# C:\Users\michi\AppData\Local\Temp/ipykernel_67988/3229610575.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   wue_D_100.mean()
# Customers_N                100.000
# Distance                213952.400
# Time                     44029.600
# Stops                      103.300
# Stops_h                      8.460
# FixedDC_Cost               480.000
# Trans_Cost                 250.512
# Variable_DC                662.270
# Fixed_V                     74.250
# Total_Cost                1467.032
# Var_per_order                6.622
# Trans_per_order              2.506
# Transp_order_with_V          3.248
# FixedDC_per_order            4.800
# Total_Cost_per_order        14.670
# Items                     4536.100
# Cost_per_item                0.325
# dtype: float64

# %%
def prof_picking_wue_D(var_factor):
    Customers = 100
    Items = 4543
    basket_size = (100/100) * 100
    COGS = 80
    Delivery_inc = (5/100)*100
    marketing = (2/100)*100
    cost_order_manipulation =  ((var_factor*Items)/Customers) + 3.248 +4.8  
    cost_order = (cost_order_manipulation/100)*100
    prof_picking = (basket_size - COGS - marketing - cost_order + Delivery_inc)
    
    return(prof_picking)

# %%
wue_D_pick= [prof_picking_wue_D(var_factor) for var_factor in var_factors_D]
wue_D_pick.reverse()
wue_D_pick
# Out:
# [6.969949,
#  7.283415999999999,
#  7.596883,
#  7.910350000000001,
#  8.223817000000002,
#  8.537284,
#  8.850751,
#  9.164217999999998,
#  9.477685,
#  9.791151999999999,
#  10.104619,
#  10.418086,
#  10.731553,
#  11.045020000000001]

# %%
D_picking_amount = [x / 100.0 for x in range(10000, 25000 ,1140)]
len(D_picking_amount)
# Out:
# 14

# %%
D_picking_amount
# Out:
# [100.0,
#  111.4,
#  122.8,
#  134.2,
#  145.6,
#  157.0,
#  168.4,
#  179.8,
#  191.2,
#  202.6,
#  214.0,
#  225.4,
#  236.8,
#  248.2]

# %%
plt.style.use("seaborn-ticks")

fig, (ax1,ax2) = plt.subplots(1,2, figsize=set_size(445))

ax1.plot(F_picking_amount, prof_picking_alb_F_list)
ax2.plot(F_picking_amount, prof_picking_wue_F_list)
ax2.plot(D_picking_amount, wue_D_pick)
ax2.plot(IS_picking_amount, wue_IS_pick)
#ax1.plot(F_picking_amount, basket_profs_F)
fig.tight_layout()
plt.show()
