# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as plticker
import warnings
warnings.filterwarnings('ignore')

# %%
tex_fonts = {
    "text.usetex": True,
    "font.family": "serif",
    "font.sans-serif": ["Palatino"],
    "axes.labelsize": 12,
    "font.size": 12,
    "legend.fontsize": 10,
    "xtick.labelsize": 11,
    "ytick.labelsize": 11
}

plt.rcParams.update(tex_fonts)

# %%
def set_size(width_pt, fraction=1, subplots=(1, 1)):

    # Width of figure (in pts)
    fig_width_pt = width_pt * fraction
    # Convert from pt to inches
    inches_per_pt = 1 / 72.27

    # Golden ratio to set aesthetic figure height
    golden_ratio = (5**.5 - 1) / 2

    # Figure width in inches
    fig_width_in = fig_width_pt * inches_per_pt
    # Figure height in inches
    fig_height_in = fig_width_in * golden_ratio * (subplots[0] / subplots[1])

    return (fig_width_in, fig_height_in)

# %%
wue_IS_low1 = pd.read_hdf("results/vehicle_cap/wue_IS100_vl_1.h5")
wue_IS_low2 =  pd.read_hdf("results/vehicle_cap/wue_IS100_vl_2.h5")
wue_IS_low3 =  pd.read_hdf("results/vehicle_cap/wue_IS100_vl_3.h5")

df_list_ = [wue_IS_low1, wue_IS_low2, wue_IS_low3]
wue_IS_low = pd.concat(df_list_, ignore_index=True)
wue_IS_low["Vehicle_per_order"] = wue_IS_low["Fixed_V"]/100
wue_IS_low
# Out:
#    Customers_N  Distance     Time  Stops  Stops_h  FixedDC_Cost  Trans_Cost  \
# 0          100  193695.0  44578.0  107.0      8.6         480.0      249.51
# 1          100  185843.0  43795.0  106.0      8.7         480.0      244.32
# 2          100  211100.0  46407.0  106.0      8.2         480.0      261.45
#
#    Variable_DC  Fixed_V  Total_Cost  Var_per_order  Trans_per_order  \
# 0      1212.16    157.5     2099.17          12.12             2.50
# 1      1164.81    135.0     2024.13          11.65             2.44
# 2      1207.64    135.0     2084.09          12.08             2.61
#
#    Transp_order_with_V  FixedDC_per_order  Total_Cost_per_order   Items  \
# 0                 4.07                4.8                 20.99  4557.0
# 1                 3.79                4.8                 20.24  4379.0
# 2                 3.96                4.8                 20.84  4540.0
#
#    Cost_per_item  Vehicle_per_order
# 0           0.46              1.575
# ...

# %%
alb_IS_low1 = pd.read_hdf("results/vehicle_cap/alb_IS100_vl_1.h5")
alb_IS_low2 =  pd.read_hdf("results/vehicle_cap/alb_IS100_vl_2.h5")
alb_IS_low3 =  pd.read_hdf("results/vehicle_cap/alb_IS100_vl_3.h5")

df_list_ = [alb_IS_low1, alb_IS_low2, alb_IS_low3]
alb_IS_low = pd.concat(df_list_, ignore_index=True)
alb_IS_low["Vehicle_per_order"] = alb_IS_low["Fixed_V"]/100
alb_IS_low
# Out:
#    Customers_N  Distance     Time  Stops  Stops_h  FixedDC_Cost  Trans_Cost  \
# 0          100  158890.0  40423.0  106.0      9.4         480.0      223.24
# 1          100  192072.0  42607.0  107.0      9.0         480.0      239.72
# 2          100  166932.0  40585.0  106.0      9.4         480.0      225.47
#
#    Variable_DC  Fixed_V  Total_Cost  Var_per_order  Trans_per_order  \
# 0      1212.16    135.0     2050.40          12.12             2.23
# 1      1164.81    157.5     2042.03          11.65             2.40
# 2      1207.64    135.0     2048.11          12.08             2.25
#
#    Transp_order_with_V  FixedDC_per_order  Total_Cost_per_order   Items  \
# 0                 3.58                4.8                 20.50  4557.0
# 1                 3.97                4.8                 20.42  4379.0
# 2                 3.60                4.8                 20.48  4540.0
#
#    Cost_per_item  Vehicle_per_order
# 0           0.45              1.350
# ...

# %%
wue_IS_high1 = pd.read_hdf("results/vehicle_cap/wue_IS100_vh_1.h5")
wue_IS_high2 =  pd.read_hdf("results/vehicle_cap/wue_IS100_vh_2.h5")
wue_IS_high3 =  pd.read_hdf("results/vehicle_cap/wue_IS100_vh_3.h5")

df_list_ = [wue_IS_high1, wue_IS_high2, wue_IS_high3]
wue_IS_high = pd.concat(df_list_, ignore_index=True)
wue_IS_high["Vehicle_per_order"] = wue_IS_high["Fixed_V"]/100
wue_IS_high

# %%
alb_IS_high1 = pd.read_hdf("results/vehicle_cap/alb_IS100_vh_1.h5")
alb_IS_high2 =  pd.read_hdf("results/vehicle_cap/alb_IS100_vh_2.h5")
alb_IS_high3 =  pd.read_hdf("results/vehicle_cap/alb_IS100_vh_3.h5")

df_list_ = [alb_IS_high1, alb_IS_high2, alb_IS_high3]
alb_IS_high = pd.concat(df_list_, ignore_index=True)
alb_IS_high["Vehicle_per_order"] = alb_IS_high["Fixed_V"]/100
alb_IS_high
# Out:
#    Customers_N  Distance     Time  Stops  Stops_h  FixedDC_Cost  Trans_Cost  \
# 0          100  160875.0  41009.0  103.0      9.0         480.0      226.42
# 1          100  138415.0  38242.0  104.0      9.8         480.0      209.05
# 2          100  167094.0  40915.0  103.0      9.1         480.0      227.09
#
#    Variable_DC  Fixed_V  Total_Cost  Var_per_order  Trans_per_order  \
# 0      1212.16     67.5     1986.08          12.12             2.26
# 1      1164.81     90.0     1943.86          11.65             2.09
# 2      1207.64     67.5     1982.23          12.08             2.27
#
#    Transp_order_with_V  FixedDC_per_order  Total_Cost_per_order   Items  \
# 0                 2.94                4.8                 19.86  4557.0
# 1                 2.99                4.8                 19.44  4379.0
# 2                 2.95                4.8                 19.82  4540.0
#
#    Cost_per_item  Vehicle_per_order
# 0           0.44              0.675
# ...

# %%
alb_IS = pd.read_hdf("results/Alb_IS100/alb_IS_100_merged.h5")
alb_IS["Vehicle_per_order"] = alb_IS["Fixed_V"]/100
alb_IS = alb_IS[0:3]
alb_IS
# Out:
#    Customers_N  Distance     Time  Stops  Stops_h  FixedDC_Cost  Trans_Cost  \
# 1          100  124502.0  36622.0  103.0     10.1         480.0      198.74
# 2          100  115313.0  35092.0  103.0     10.6         480.0      189.73
# 3          100  136959.0  37775.0  103.0      9.8         480.0      206.54
#
#    Variable_DC  Fixed_V  Total_Cost  Var_per_order  Trans_per_order  \
# 1      1212.16     67.5     1958.40          12.12             1.99
# 2      1136.62     67.5     1873.85          11.37             1.90
# 3      1207.64     67.5     1961.68          12.08             2.07
#
#    Transp_order_with_V  FixedDC_per_order  Total_Cost_per_order   Items  \
# 1                 2.66                4.8                 19.58  4557.0
# 2                 2.57                4.8                 18.74  4273.0
# 3                 2.74                4.8                 19.62  4540.0
#
#    Cost_per_item      City  Scenario  Vehicle_per_order
# ...

# %%
alb_IS_low_transp = alb_IS_low["Trans_per_order"].mean()
alb_IS_low_vehicle = alb_IS_low["Vehicle_per_order"].mean()
print(alb_IS_low_transp)
print(alb_IS_low_vehicle)
# Out:
# 2.2933333333333334
# 1.425

# %%
alb_IS_transp = alb_IS["Trans_per_order"].mean()
alb_IS_vehicle = alb_IS["Vehicle_per_order"].mean()
print(alb_IS_transp)
print(alb_IS_vehicle)
# Out:
# 1.9866666666666664
# 0.6750000000000002

# %%
alb_IS_high_transp = alb_IS_high["Trans_per_order"].mean()
alb_IS_high_vehicle = alb_IS_high["Vehicle_per_order"].mean()
print(alb_IS_high_transp)
print(alb_IS_high_vehicle)
# Out:
# 2.2066666666666666
# 0.75

# %%
alb_l_t = list([alb_IS_low_transp, alb_IS_transp,alb_IS_high_transp])
alb_l_t
# Out:
# [2.2933333333333334, 2.011, 2.2066666666666666]

# %%
alb_l_v = list([alb_IS_low_vehicle, alb_IS_vehicle,alb_IS_high_vehicle])
alb_l_v
# Out:
# [1.425, 0.6750000000000002, 0.75]

# %%
albtest = [alb_l_v[0], alb_l_v[1]]
albtest
# Out:
# [1.425, 0.6750000000000002]

# %%
from operator import add
alb_total = list( map(add,alb_l_t, alb_l_v) )
alb_total
# Out:
# [3.7183333333333337, 2.6860000000000004, 2.9566666666666666]

# %%
plt.style.use("seaborn-ticks")

xticks = [1,2,3]
labels = ["875","1750", "2725"]



fig, ax1 = plt.subplots(1,1, figsize=set_size(500))

fig.supxlabel("\\textbf{Vehicle Capacity}", y = 0.05, fontsize=12)
ax1.set_title("\\textbf{Albstadt}", fontsize=14)
#ax2.set_title("\\textbf{Würzburg}", fontsize=14)
ax1.set_ylabel("\\textbf{Average Cost/Order in €")

ax1.plot(labels, alb_l_t, color="#ff7f0e", label = "Transportation")
ax1.plot(labels, alb_l_v, color = "#1f77b4", label = "Fixed Vehicle")
ax1.plot(labels, alb_total, color = "black", label = "Total")

ax1.yaxis.grid(True)
handles, labels = ax1.get_legend_handles_labels()
fig.legend(handles, labels, loc='lower left', frameon=True,
           fancybox=True, ncol=1, borderpad=0.1, labelspacing = 0.2, borderaxespad=0.1)
fig.tight_layout()
plt.show()

# %%
alb_low_tlist = alb_IS_low["Trans_per_order"].tolist()
alb_low_vlist = alb_IS_low["Vehicle_per_order"].tolist()

alb_tlist = alb_IS["Trans_per_order"].tolist()
alb_vlist = alb_IS["Vehicle_per_order"].tolist()

alb_high_tlist = alb_IS_high["Trans_per_order"].tolist()
alb_high_vlist = alb_IS_high["Vehicle_per_order"].tolist()

# %%
alb_t = [alb_low_tlist, alb_tlist, alb_high_tlist]
alb_v =  [alb_low_vlist, alb_vlist, alb_high_vlist]

# %%
plt.style.use("seaborn-ticks")

xticks = [1,2,3]
labels = ["875","1750", "2725"]



fig, ax1 = plt.subplots(1,1, figsize=set_size(500))

fig.supxlabel("\\textbf{Vehicle Capacity}", y = 0.05, fontsize=12)
ax1.set_title("\\textbf{Albstadt}", fontsize=14)
#ax2.set_title("\\textbf{Würzburg}", fontsize=14)
ax1.set_ylabel("\\textbf{Cost/Order in €")

ax1.boxplot(alb_t, 
           patch_artist=True, widths=0.4,
           boxprops=dict(facecolor="grey", color="black"),
           medianprops=dict(color="black"))
#ax1.boxplot(alb_v, 
#           patch_artist=True, widths=0.4,
#           boxprops=dict(facecolor="grey", color="black"),
#           medianprops=dict(color="black"))
ax1.scatter(xticks, alb_l_v, color = "#1f77b4", label = "Fixed Vehicle")
ax1.yaxis.grid(True)
ax1.set_xticks(xticks)
ax1.set_xticklabels(labels, rotation = 0)
#handles, labels = ax1.get_legend_handles_labels()
#fig.legend(handles, labels, loc='lower left', frameon=True,
           #fancybox=True, ncol=1, borderpad=0.1, labelspacing = 0.2, borderaxespad=0.1)
fig.tight_layout()
plt.show()
