# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as plticker
import warnings
warnings.filterwarnings('ignore')

# %%
tex_fonts = {
    "text.usetex": True,
    "font.family": "serif",
    "font.sans-serif": ["Palatino"],
    "axes.labelsize": 12,
    "font.size": 12,
    "legend.fontsize": 10,
    "xtick.labelsize": 11,
    "ytick.labelsize": 11
}

plt.rcParams.update(tex_fonts)

# %%
def set_size(width_pt, fraction=1, subplots=(1, 1)):

    # Width of figure (in pts)
    fig_width_pt = width_pt * fraction
    # Convert from pt to inches
    inches_per_pt = 1 / 72.27

    # Golden ratio to set aesthetic figure height
    golden_ratio = (5**.5 - 1) / 2

    # Figure width in inches
    fig_width_in = fig_width_pt * inches_per_pt
    # Figure height in inches
    fig_height_in = fig_width_in * golden_ratio * (subplots[0] / subplots[1])

    return (fig_width_in, fig_height_in)

# %%
wue_IS_pup_A = pd.read_hdf("results/PuP/Wue_IS_pup_A/wue_IS_pup_A_merged.h5")
wue_IS_pup_B =  pd.read_hdf("results/PuP/Wue_IS_pup_B/wue_IS_pup_B_merged.h5")
wue_IS_pup_C =  pd.read_hdf("results/PuP/Wue_IS_pup_C/wue_IS_pup_C_merged.h5")

df_list_ = [wue_IS_pup_A, wue_IS_pup_B, wue_IS_pup_C]
wue_IS = pd.concat(df_list_, ignore_index=True)
wue_IS = wue_IS.sort_values(by=['D_Scenario'])
wue_IS
# Out:
#     Customers_N  Distance     Time  Stops  Stops_h  FixedDC_Cost  Trans_Cost  \
# 59           25  114092.0  19915.0   30.0      5.4    720.000000      116.43
# 19            6   45926.0   6289.0   12.0      6.9    720.000000       38.55
# 18            6   45926.0   6289.0   12.0      6.9    720.000000       38.55
# 17            6   45926.0   6289.0   12.0      6.9    720.000000       38.55
# 16            6   45926.0   6289.0   12.0      6.9    720.000000       38.55
# 15            6   45926.0   6289.0   12.0      6.9    720.000000       38.55
# 58           25   97704.0  18186.0   31.0      6.1    720.000000      105.16
# 35           10   66008.0   9806.0   15.0      5.5    720.000000       59.10
# 36           10   53742.0   8961.0   15.0      6.0    720.000000       52.82
# 38           10   55211.0   9332.0   15.0      5.8    720.000000       54.87
# 37           10   53284.0   8880.0   15.0      6.1    720.000000       52.35
# ...

# %%
wue_IS.D_Scenario=pd.Categorical(wue_IS.D_Scenario,categories=['very_low', 'low', 'mid', "high"])
wue_IS=wue_IS.sort_values('D_Scenario')
wue_IS.loc[wue_IS['D_Scenario'] == "very_low", 'Cost_Order'] = wue_IS["Total_Cost"]/25
wue_IS.loc[wue_IS['D_Scenario'] == "low", 'Cost_Order'] = wue_IS["Total_Cost"]/50
wue_IS.loc[wue_IS['D_Scenario'] == "mid", 'Cost_Order'] = wue_IS["Total_Cost"]/100
wue_IS.loc[wue_IS['D_Scenario'] == "high", 'Cost_Order'] = wue_IS["Total_Cost"]/150
wue_IS
# Out:
#     Customers_N  Distance     Time  Stops  Stops_h  FixedDC_Cost  Trans_Cost  \
# 0             6   41776.0   6107.0    7.0      4.1    240.000000       36.93
# 43           25   86215.0  17170.0   26.0      5.5    240.000000       98.19
# 22           10   44894.0   7842.0   11.0      5.0    240.000000       45.84
# 21           10   44894.0   7842.0   11.0      5.0    240.000000       45.84
# 20           10   44894.0   7843.0   11.0      5.0    240.000000       45.84
# 41           25   79675.0  16768.0   26.0      5.6    240.000000       95.08
# 24           10   44894.0   7843.0   11.0      5.0    240.000000       45.84
# 40           25   82687.0  17164.0   26.0      5.5    240.000000       97.52
# 44           25   79662.0  16715.0   26.0      5.6    240.000000       94.82
# 42           25   84894.0  16672.0   26.0      5.6    240.000000       95.56
# 1             6   40911.0   5834.0    7.0      4.3    240.000000       35.45
# ...

# %%
wue_IS_list = wue_IS["Cost_Order"].tolist()
wue_IS_list= [wue_IS_list[x:x+15] for x in range(0, len(wue_IS_list), 15)]
wue_IS_list
# Out:
# [[24.7876,
#   28.323600000000003,
#   22.0372,
#   22.4096,
#   24.2824,
#   25.9648,
#   23.1544,
#   26.7008,
#   26.252,
#   25.8456,
#   23.2284,
#   21.992800000000003,
#   25.156799999999997,
#   23.340799999999998,
#   25.538],
#  [19.525,
#   17.7164,
#   19.8624,
#   19.151400000000002,
#   18.9852,
#   21.629,
#   18.304000000000002,
#   19.988599999999998,
#   18.2482,
#   19.054000000000002,
#   17.677,
#   19.2626,
#   18.3306,
#   19.0624,
#   17.4558],
#  [18.1598,
#   18.5918,
#   18.038800000000002,
#   20.0369,
#   18.3367,
#   18.7756,
#   17.9028,
#   17.9235,
#   18.1361,
#   19.2425,
#   17.7725,
#   18.6917,
#   18.286099999999998,
#   18.8812,
#   17.8538],
#  [18.276866666666667,
#   18.610533333333333,
#   18.762999999999998,
#   19.178333333333335,
#   18.862933333333334,
#   18.106199999999998,
#   18.428866666666668,
#   20.234866666666665,
#   18.678866666666668,
#   18.224933333333333,
#   18.733866666666668,
#   18.437733333333334,
# ...

# %%
def Average(lst):
    return sum(lst) / len(lst)

wue_IS_avg = list(map(Average, wue_IS_list))

# %%
wue_IS_avg
# Out:
# [24.600986666666667,
#  18.950173333333336,
#  18.441986666666665,
#  18.674666666666667]

# %%
wue_D_pup_A = pd.read_hdf("results/PuP/Wue_D_pup_A/wue_D_pup_A_merged.h5")
wue_D_pup_B =  pd.read_hdf("results/PuP/Wue_D_pup_B/wue_D_pup_B_merged.h5")
wue_D_pup_C =  pd.read_hdf("results/PuP/Wue_D_pup_C/wue_D_pup_C_merged.h5")

df_list_ = [wue_D_pup_A, wue_D_pup_B, wue_D_pup_C]
wue_D = pd.concat(df_list_, ignore_index=True)

wue_D.D_Scenario=pd.Categorical(wue_D.D_Scenario,categories=['very_low', 'low', 'mid', "high"])
wue_D = wue_D.sort_values(by=['D_Scenario'])
wue_D.loc[wue_D['D_Scenario'] == "very_low", 'Cost_Order'] = wue_D["Total_Cost"]/25
wue_D.loc[wue_D['D_Scenario'] == "low", 'Cost_Order'] = wue_D["Total_Cost"]/50
wue_D.loc[wue_D['D_Scenario'] == "mid", 'Cost_Order'] = wue_D["Total_Cost"]/100
wue_D.loc[wue_D['D_Scenario'] == "high", 'Cost_Order'] = wue_D["Total_Cost"]/150
wue_D
# Out:
#     Customers_N   Distance      Time      Stops  Stops_h  FixedDC_Cost  \
# 0             6   60389.00   6830.00   7.000000      3.7         480.0
# 21           10   64028.00   8883.00  11.000000      4.5         480.0
# 20           10   64028.00   8883.00  11.000000      4.5         480.0
# 24           10   64028.00   8883.00  11.000000      4.5         480.0
# 40           25   98376.00  17558.00  26.000000      5.3         480.0
# 41           25   98376.00  17558.00  26.000000      5.3         480.0
# 42           25   98376.00  17558.00  26.000000      5.3         480.0
# 22           10   64028.00   8883.00  11.000000      4.5         480.0
# 44           25   98376.00  17558.00  26.000000      5.3         480.0
# 43           25   98376.00  17558.00  26.000000      5.3         480.0
# 4             6   60389.00   6830.00   7.000000      3.7         480.0
# 3             6   60389.00   6830.00   7.000000      3.7         480.0
# ...

# %%
wue_D_list = wue_D["Cost_Order"].tolist()
wue_D_list= [wue_D_list[x:x+15] for x in range(0, len(wue_D_list), 15)]
wue_D_avg = list(map(Average, wue_D_list))
wue_D_avg
# Out:
# [29.20378666666667, 18.654639999999997, 13.101579999999997, 11.733155555555555]

# %%
wue_F_pup_A = pd.read_hdf("results/PuP/Wue_F_pup_A/wue_F_pup_A_merged_new.h5")
wue_F_pup_B =  pd.read_hdf("results/PuP/Wue_F_pup_B/wue_F_pup_B_merged.h5")
wue_F_pup_C =  pd.read_hdf("results/PuP/Wue_F_pup_C/wue_F_pup_C_merged.h5")

df_list_ = [wue_F_pup_A, wue_F_pup_B, wue_F_pup_C]
wue_F = pd.concat(df_list_, ignore_index=True)

wue_F.D_Scenario=pd.Categorical(wue_F.D_Scenario,categories=['very_low', 'low', 'mid', "high"])
wue_F = wue_F.sort_values(by=['D_Scenario'])
wue_F['Total_Cost'] = np.where(wue_F['FixedDC_Cost'] == 640, wue_F["Total_Cost"] -60 , wue_F['Total_Cost'])
wue_F["FixedDC_Cost"] = 560
wue_F.loc[wue_F['D_Scenario'] == "very_low", 'Cost_Order'] = wue_F["Total_Cost"]/25
wue_F.loc[wue_F['D_Scenario'] == "low", 'Cost_Order'] = wue_F["Total_Cost"]/50
wue_F.loc[wue_F['D_Scenario'] == "mid", 'Cost_Order'] = wue_F["Total_Cost"]/100
wue_F.loc[wue_F['D_Scenario'] == "high", 'Cost_Order'] = wue_F["Total_Cost"]/150
wue_F
# Out:
#     Customers_N   Distance      Time      Stops  Stops_h  FixedDC_Cost  \
# 0             6   60835.00   6936.00   7.000000      3.6           560
# 21           10   64028.00   8883.00  11.000000      4.5           560
# 20           10   64028.00   8883.00  11.000000      4.5           560
# 24           10   64028.00   8883.00  11.000000      4.5           560
# 40           25  102955.00  18023.00  26.000000      5.2           560
# 41           25  102955.00  18023.00  26.000000      5.2           560
# 42           25  102955.00  18023.00  26.000000      5.2           560
# 22           10   64028.00   8883.00  11.000000      4.5           560
# 44           25  102955.00  18023.00  26.000000      5.2           560
# 43           25  102955.00  18023.00  26.000000      5.2           560
# 4             6   60835.00   6936.00   7.000000      3.6           560
# 3             6   60835.00   6936.00   7.000000      3.6           560
# ...

# %%
wue_F_list = wue_F["Cost_Order"].tolist()
wue_F_list= [wue_F_list[x:x+15] for x in range(0, len(wue_F_list), 15)]
wue_F_avg = list(map(Average, wue_F_list))
wue_F_avg
# Out:
# [30.342106666666666, 17.800560000000004, 11.273406666666665, 9.506546666666667]

# %%
wue_F_HD = pd.read_hdf("wue_F_merged.h5")
wue_F_HD
# Out:
#     Customers_N   Distance      Time       Stops  Stops_h  FixedDC_Cost  \
# 0            25   75320.00  13611.00   26.000000      6.9           560
# 1            25   94867.00  16272.00   26.000000      5.8           560
# 2            25   92854.00  15226.00   26.000000      6.1           560
# 3            25   96497.00  14937.00   26.000000      6.3           560
# 4            25   92800.00  14851.00   26.000000      6.3           560
# 5            25   77790.00  13366.00   26.000000      7.0           560
# 6            25   95936.00  15298.00   26.000000      6.1           560
# 7            25   93214.00  14807.00   26.000000      6.3           560
# 8            25   81493.00  13662.00   26.000000      6.9           560
# 9            25   77908.00  13326.00   26.000000      7.0           560
# 10           50  123694.00  23269.00   52.000000      8.0           560
# 11           50  136054.00  25843.00   52.000000      7.2           560
# ...

# %%
wue_F_HD_list = wue_F_HD["Total_Cost_per_order"].tolist()
wue_F_HD_list= [wue_F_HD_list[x:x+10] for x in range(0, len(wue_F_HD_list), 10)]
wue_F_HD_avg = list(map(Average, wue_F_HD_list))
wue_F_HD_avg
# Out:
# [30.714, 18.892, 12.75, 10.873]

# %%
wue_IS_HD = pd.read_hdf("wue_IS_merged.h5")
wue_D_HD = pd.read_hdf("wue_D_merged.h5")

wue_IS_HD_list = wue_IS_HD["Total_Cost_per_order"].tolist()
wue_IS_HD_list= [wue_IS_HD_list[x:x+10] for x in range(0, len(wue_IS_HD_list), 10)]
wue_IS_HD_avg = list(map(Average, wue_IS_HD_list))
wue_IS_HD_avg

wue_D_HD_list = wue_D_HD["Total_Cost_per_order"].tolist()
wue_D_HD_list= [wue_D_HD_list[x:x+10] for x in range(0, len(wue_D_HD_list), 10)]
wue_D_HD_avg = list(map(Average, wue_D_HD_list))
wue_D_HD_avg
# Out:
# [30.174, 20.059999999999995, 14.669999999999996, 13.029000000000002]

# %%
wue_IS_HD_avg
# Out:
# [25.805999999999994, 20.395999999999997, 19.799, 19.948]

# %%
plt.style.use("seaborn-ticks")

xticks = [1,2,3,4]
labels = ["$25$C","$50$C", "$100$C", "$150$C"]



fig, (ax1, ax2) = plt.subplots(1,2, figsize=set_size(500))

fig.supxlabel("\\textbf{Demand Scenario}", y = 0.05, fontsize=12)
ax1.set_title("\\textbf{Würzburg}", fontsize=14)

ax1.set_ylabel("\\textbf{Cost/Order in €")

ax1.plot(labels,wue_IS_HD_avg, marker = "s", ms=4, label="In Store", color="#207720", alpha = 0.4)
ax1.plot(labels, wue_D_HD_avg, marker = "o", ms=4, label = "Darkstore", color="#234990", alpha = 0.4)
ax1.plot(labels, wue_F_HD_avg, marker = "x", ms=4, label= "FC", color = "#E23726", alpha = 0.4)

ax1.plot(labels,wue_IS_avg, marker = "s", ms=4, label="In Store", color="#207720")
ax1.plot(labels, wue_D_avg, marker = "o", ms=4, label = "Darkstore", color="#234990")
ax1.plot(labels, wue_F_avg, marker = "x", ms=4, label= "FC", color = "#E23726")
ax1.yaxis.grid(True)

#ax1.set_ylim(ymax = 35, ymin =10)

handles, labels = ax1.get_legend_handles_labels()
fig.legend(handles, labels, loc='lower left', frameon=True,
           fancybox=True, ncol=1, borderpad=0.1, labelspacing = 0.2, borderaxespad=0.1)


fig.tight_layout()
plt.show()
#fig.savefig("result_graph/comp_methods_and_demand.svg", format = "svg")

# %%
wue_D_25 = wue_D_list[0]
wue_D_50 = wue_D_list[1]
wue_D_100 = wue_D_list[2]
wue_D_150 = wue_D_list[3]

# %%
wue_D_25
# Out:
# [28.8816,
#  27.8024,
#  28.8304,
#  28.211199999999998,
#  30.9412,
#  30.590799999999998,
#  30.5148,
#  27.598000000000003,
#  30.754,
#  31.8172,
#  28.087600000000002,
#  29.062800000000003,
#  27.386799999999997,
#  28.058400000000002,
#  29.5196]

# %%
wue_D_HD_25 = wue_D_HD_list[0]
wue_D_HD_50 = wue_D_HD_list[1]
wue_D_HD_100 = wue_D_HD_list[2]
wue_D_HD_150 = wue_D_HD_list[3]

# %%
wue_D_HD_50
# Out:
# [19.96, 20.0, 20.01, 20.6, 20.04, 20.05, 19.93, 19.71, 20.32, 19.98]

# %%
wue_F_25 = wue_F_list[0]
wue_F_50 = wue_F_list[1]
wue_F_100 = wue_F_list[2]
wue_F_150 = wue_F_list[3]

# %%
plt.style.use("seaborn-ticks")
xticks = [0,2,4,6]
labels = ["$25$C","$50$C", "$100$C", "$150$C"]

pul_wue_D = [wue_D_25, wue_D_50, wue_D_100, wue_D_150]
hd_wue_D = [wue_D_HD_25, wue_D_HD_50, wue_D_HD_100,wue_D_HD_150 ]

pul_wue_F = [wue_F_25, wue_F_50, wue_F_100, wue_F_150]

fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=set_size(510))

ax2.set_title("\\textbf{Darkstore}", fontsize=14)

ax2.boxplot(hd_wue_D, 
           patch_artist=True, widths=1.5,
           boxprops=dict(facecolor='#1f77b4', color="black"),
           medianprops=dict(color="black"),
            positions=np.array(
    np.arange(len(hd_wue_D)))*2-0.35,)

ax2.boxplot(pul_wue_D, patch_artist=True, widths=1.5, showfliers=False,
           boxprops=dict(facecolor='#ff7f0e', color="black"),
           medianprops=dict(color="black"),
        positions=np.array(
    np.arange(len(pul_wue_D)))*2+0.35,)



ax2.set_xticks(xticks)
ax2.set_xticklabels(labels, rotation = 0)

ax2.yaxis.grid(True)

fig.tight_layout()
#fig.savefig("result_graph/HD_PUL_comparison.svg", format="svg")
plt.show()

# %%
plt.style.use("seaborn-ticks")

xticks = [1,2,3,4]
labels = ["$25$C","$50$C", "$100$C", "$150$C"]



fig, (ax1, ax2,ax3) = plt.subplots(1,3, figsize=set_size(500))

fig.supxlabel("\\textbf{Demand Scenario}", y = 0.05, fontsize=12)
ax1.set_title("\\textbf{In Store}", fontsize=14)
ax2.set_title("\\textbf{Darkstore}", fontsize=14)
ax3.set_title("\\textbf{FC}", fontsize=14)

ax1.set_ylabel("\\textbf{Cost/Order in €")

ax1.plot(labels,wue_IS_HD_avg, marker = "s", ms=4, label="Home Delivery", color="#1f77b4", alpha = 1)
ax2.plot(labels, wue_D_HD_avg, marker = "o", ms=4, label = "Darkstore", color="#1f77b4", alpha = 1)
ax3.plot(labels, wue_F_HD_avg, marker = "x", ms=4, label= "FC", color = "#1f77b4", alpha = 1)

ax1.plot(labels,wue_IS_avg, marker = "s", ms=4, label="PUL", color="#ff7f0e")
ax2.plot(labels, wue_D_avg, marker = "o", ms=4, label = "Darkstore", color="#ff7f0e")
ax3.plot(labels, wue_F_avg, marker = "x", ms=4, label= "FC", color = "#ff7f0e")
ax1.yaxis.grid(True)
ax2.yaxis.grid(True)
ax3.yaxis.grid(True)

#ax1.set_ylim(ymax = 35, ymin =10)

handles, labels = ax1.get_legend_handles_labels()
fig.legend(handles, labels, loc='lower left', frameon=True,
           fancybox=True, ncol=1, borderpad=0.1, labelspacing = 0.2, borderaxespad=0.1)


fig.tight_layout()
plt.show()
#fig.savefig("result_graph/comp_methods_and_demand.svg", format = "svg")

# %%
alb_IS_pup_A = pd.read_hdf("results/PuP/Alb_IS_pup_A/alb_IS_pup_A_merged.h5")
alb_IS_pup_B =  pd.read_hdf("results/PuP/Alb_IS_pup_B/alb_IS_pup_B_merged.h5")
alb_IS_pup_C =  pd.read_hdf("results/PuP/Alb_IS_pup_C/alb_IS_pup_C_merged.h5")

df_list_ = [alb_IS_pup_A, alb_IS_pup_B, alb_IS_pup_C]
alb_IS = pd.concat(df_list_, ignore_index=True)
alb_IS.D_Scenario=pd.Categorical(alb_IS.D_Scenario,categories=['very_low', 'low', 'mid', "high"])
alb_IS=alb_IS.sort_values('D_Scenario')
alb_IS.loc[alb_IS['D_Scenario'] == "very_low", 'Cost_Order'] = alb_IS["Total_Cost"]/25
alb_IS.loc[alb_IS['D_Scenario'] == "low", 'Cost_Order'] = alb_IS["Total_Cost"]/50
alb_IS.loc[alb_IS['D_Scenario'] == "mid", 'Cost_Order'] = alb_IS["Total_Cost"]/100
alb_IS.loc[alb_IS['D_Scenario'] == "high", 'Cost_Order'] = alb_IS["Total_Cost"]/150
alb_IS
# Out:
#     Customers_N  Distance     Time      Stops  Stops_h  FixedDC_Cost  \
# 0             4  26534.00  3341.00   5.000000      5.4    240.000000
# 21            8  35745.00  5373.00   9.000000      6.0    240.000000
# 20            8  35745.00  5373.00   9.000000      6.0    240.000000
# 24            8  35745.00  5373.00   9.000000      6.0    240.000000
# 40           14  45093.00  8397.00  15.000000      6.4    240.000000
# 41           14  45093.00  8397.00  15.000000      6.4    240.000000
# 42           14  45092.99  8397.00  14.999995      6.4    240.000000
# 22            8  35745.00  5373.00   9.000000      6.0    240.000000
# 44           14  45093.00  8397.00  15.000000      6.4    240.000000
# 43           14  45093.00  8397.00  14.999998      6.4    240.000000
# 4             4  26534.00  3341.00   5.000000      5.4    240.000000
# 3             4  26534.00  3341.00   5.000000      5.4    240.000000
# 2             4  26534.00  3341.00   5.000000      5.4    240.000000
# ...

# %%
alb_IS_list = alb_IS["Cost_Order"].tolist()
alb_IS_list= [alb_IS_list[x:x+15] for x in range(0, len(alb_IS_list), 15)]
alb_IS_avg = list(map(Average, alb_IS_list))
alb_IS_avg
# Out:
# [23.25453333333333, 18.32222666666667, 18.498400000000004, 18.032528888888887]

# %%
alb_D_pup_A = pd.read_hdf("results/PuP/Alb_D_pup_A/alb_D_pup_A_merged.h5")
alb_D_pup_B =  pd.read_hdf("results/PuP/Alb_D_pup_B/alb_D_pup_B_merged.h5")
alb_D_pup_C =  pd.read_hdf("results/PuP/Alb_D_pup_C/alb_D_pup_C_merged.h5")

df_list_ = [alb_D_pup_A, alb_D_pup_B, alb_D_pup_C]
alb_D = pd.concat(df_list_, ignore_index=True)

alb_D.D_Scenario=pd.Categorical(alb_D.D_Scenario,categories=['very_low', 'low', 'mid', "high"])
alb_D = alb_D.sort_values(by=['D_Scenario'])
alb_D.loc[alb_D['D_Scenario'] == "very_low", 'Cost_Order'] = alb_D["Total_Cost"]/25
alb_D.loc[alb_D['D_Scenario'] == "low", 'Cost_Order'] = alb_D["Total_Cost"]/50
alb_D.loc[alb_D['D_Scenario'] == "mid", 'Cost_Order'] = alb_D["Total_Cost"]/100
alb_D.loc[alb_D['D_Scenario'] == "high", 'Cost_Order'] = alb_D["Total_Cost"]/150
alb_D
# Out:
#     Customers_N   Distance      Time      Stops  Stops_h  FixedDC_Cost  \
# 0             4   35460.00   3832.00   5.000000      4.7    480.000000
# 21            8   48195.00   6191.00   9.000000      5.2    480.000000
# 20            8   38146.00   5481.00   8.999999      5.9    480.000000
# 24            8   38146.00   5481.00   8.999999      5.9    480.000000
# 40           14   49543.00   8596.00  15.000000      6.3    480.000000
# 41           14   49542.95   8595.99  14.999986      6.3    480.000000
# 42           14   49542.95   8595.99  14.999986      6.3    480.000000
# 22            8   38146.00   5481.00   8.999999      5.9    480.000000
# 44           14   49542.99   8596.00  14.999993      6.3    480.000000
# 43           14   49543.00   8596.00  15.000000      6.3    479.999998
# 4             4   35460.00   3832.00   5.000000      4.7    480.000000
# 3             4   35460.00   3832.00   5.000000      4.7    480.000000
# ...

# %%
alb_D_list = alb_D["Cost_Order"].tolist()
alb_D_list= [alb_D_list[x:x+15] for x in range(0, len(alb_D_list), 15)]
alb_D_avg = list(map(Average, alb_D_list))
alb_D_avg
# Out:
# [27.524933333333333,
#  17.917239999999996,
#  12.986133333333331,
#  11.187111111111111]

# %%
alb_F_pup_A = pd.read_hdf("results/PuP/Alb_F_pup_A/alb_F_pup_A_merged_new.h5")
alb_F_pup_B =  pd.read_hdf("results/PuP/Alb_F_pup_B/alb_F_pup_B_merged.h5")
alb_F_pup_C =  pd.read_hdf("results/PuP/Alb_F_pup_C/alb_F_pup_C_merged.h5")

df_list_ = [alb_F_pup_A, alb_F_pup_B, alb_F_pup_C]
alb_F = pd.concat(df_list_, ignore_index=True)

alb_F.D_Scenario=pd.Categorical(alb_F.D_Scenario,categories=['very_low', 'low', 'mid', "high"])
alb_F = alb_F.sort_values(by=['D_Scenario'])
alb_F['Total_Cost'] = np.where(alb_F['FixedDC_Cost'] == 640, alb_F["Total_Cost"] -60 , alb_F['Total_Cost'])
alb_F["FixedDC_Cost"] = 560
alb_F.loc[alb_F['D_Scenario'] == "very_low", 'Cost_Order'] = alb_F["Total_Cost"]/25
alb_F.loc[alb_F['D_Scenario'] == "low", 'Cost_Order'] = alb_F["Total_Cost"]/50
alb_F.loc[alb_F['D_Scenario'] == "mid", 'Cost_Order'] = alb_F["Total_Cost"]/100
alb_F.loc[alb_F['D_Scenario'] == "high", 'Cost_Order'] = alb_F["Total_Cost"]/150
alb_F
# Out:
#     Customers_N   Distance      Time      Stops  Stops_h  FixedDC_Cost  \
# 0             4   35460.00   3832.00   5.000000      4.7           560
# 21            8   63130.00   7449.00   9.000000      4.3           560
# 20            8   63130.00   7449.00   9.000000      4.3           560
# 24            8   63130.00   7449.00   9.000000      4.3           560
# 40           14   49543.00   8596.00  15.000000      6.3           560
# 41           14   49543.00   8596.00  15.000000      6.3           560
# 42           14   49543.00   8596.00  15.000000      6.3           560
# 22            8   63130.00   7449.00   9.000000      4.3           560
# 44           14   49542.99   8596.00  14.999997      6.3           560
# 43           14   49543.00   8596.00  15.000000      6.3           560
# 4             4   35460.00   3832.00   5.000000      4.7           560
# 3             4   35460.00   3832.00   5.000000      4.7           560
# ...

# %%
alb_F_list = alb_F["Cost_Order"].tolist()
alb_F_list= [alb_F_list[x:x+15] for x in range(0, len(alb_F_list), 15)]
alb_F_avg = list(map(Average, alb_F_list))
alb_F_avg
# Out:
# [29.150080000000003, 17.091746666666666, 11.095659999999999, 8.998977777777778]

# %%
alb_IS_HD = pd.read_hdf("alb_IS_merged.h5")
alb_D_HD = pd.read_hdf("alb_D_merged.h5")
alb_F_HD = pd.read_hdf("alb_F_merged.h5")

alb_IS_HD_list = alb_IS_HD["Total_Cost_per_order"].tolist()
alb_IS_HD_list= [alb_IS_HD_list[x:x+10] for x in range(0, len(alb_IS_HD_list), 10)]
alb_IS_HD_avg = list(map(Average, alb_IS_HD_list))
alb_IS_HD_avg

alb_D_HD_list = alb_D_HD["Total_Cost_per_order"].tolist()
alb_D_HD_list= [alb_D_HD_list[x:x+10] for x in range(0, len(alb_D_HD_list), 10)]
alb_D_HD_avg = list(map(Average, alb_D_HD_list))
alb_D_HD_avg

alb_F_HD_list = alb_F_HD["Total_Cost_per_order"].tolist()
alb_F_HD_list= [alb_F_HD_list[x:x+10] for x in range(0, len(alb_F_HD_list), 10)]
alb_F_HD_avg = list(map(Average, alb_F_HD_list))
alb_F_HD_avg
# Out:
# [30.238000000000007, 18.429000000000002, 12.487, 10.55]

# %%
join_F = pd.concat([alb_F, wue_F])
join_F
# Out:
#     Customers_N  Distance     Time  Stops  Stops_h  FixedDC_Cost  Trans_Cost  \
# 0             4   35460.0   3832.0    5.0      4.7           560       24.83
# 21            8   63130.0   7449.0    9.0      4.3           560       47.23
# 20            8   63130.0   7449.0    9.0      4.3           560       47.23
# 24            8   63130.0   7449.0    9.0      4.3           560       47.23
# 40           14   49543.0   8596.0   15.0      6.3           560       50.31
# ..          ...       ...      ...    ...      ...           ...         ...
# 15            6  203848.0  15278.0   12.0      2.8           560      110.25
# 16            6  203848.0  15278.0   12.0      2.8           560      110.25
# 17            6  203848.0  15278.0   12.0      2.8           560      110.25
# 19            6  203848.0  15278.0   12.0      2.8           560      110.25
# 59           25  197486.0  23499.0   30.0      4.6           560      148.70
#
# ...

# %%
F = join_F.groupby("D_Scenario").mean()
F
# Out:
#             Customers_N       Distance          Time      Stops   Stops_h  \
# D_Scenario
# very_low      11.166667   62658.499667   8953.166667  12.166667  4.766667
# low           11.166667   76033.293000   9620.732333  13.166665  4.863333
# mid           11.166667  103755.020667  11392.498000  14.333331  4.436667
# high          11.166667  150219.261333  14220.299667  16.099999  4.080000
#
#             FixedDC_Cost  Trans_Cost  Variable_DC     Fixed_V   Total_Cost  \
# D_Scenario
# very_low           560.0   54.388333    93.430667   22.499999   743.652333
# low                560.0   60.009667   193.964667   44.999995   872.307667
# mid                560.0   73.528333   400.341667   71.249992  1118.453333
# high               560.0   95.509333   608.071667  110.999995  1387.914333
#
#             Var_per_order  Trans_per_order  Transp_order_with_V  \
# D_Scenario
# very_low        11.609000         5.455000             8.280000
# ...

# %%
join_D = pd.concat([alb_D, wue_D])
D = join_D.groupby("D_Scenario").mean()
D
# Out:
#             Customers_N       Distance          Time      Stops  Stops_h  \
# D_Scenario
# very_low      11.166667   58252.229667   8566.366000  12.166665     5.03
# low           11.166667   75971.597667   9622.599667  13.166666     4.86
# mid           11.166667  103658.985667  11387.231667  14.333331     4.44
# high          11.166667  150569.461000  14249.332667  16.099999     4.07
#
#             FixedDC_Cost  Trans_Cost  Variable_DC     Fixed_V   Total_Cost  \
# D_Scenario
# very_low           480.0   51.734333   154.874667   22.499993   709.109000
# low                480.0   60.008333   329.288667   44.999998   914.297000
# mid                480.0   73.486000   679.649667   71.249989  1304.385667
# high               480.0   95.712333  1032.307667  110.999996  1719.020000
#
#             Var_per_order  Trans_per_order  Transp_order_with_V  \
# D_Scenario
# very_low        19.003333         5.177000             8.000333
# ...

# %%
join_IS = pd.concat([alb_IS, wue_IS])
IS = join_IS.groupby("D_Scenario").mean()
IS
# Out:
#             Customers_N      Distance         Time      Stops   Stops_h  \
# D_Scenario
# very_low      11.166667  46179.366333  7974.800000  12.166666  5.426667
# low           11.166667  45901.766667  8018.533333  13.166667  5.896667
# mid           11.166667  53861.898000  8683.066333  14.599999  6.466667
# high          11.166667  56072.100000  9017.000000  16.366667  6.880000
#
#             FixedDC_Cost  Trans_Cost  Variable_DC     Fixed_V   Total_Cost  \
# D_Scenario
# very_low      240.000000   46.711333   288.982667   22.499999   598.194000
# low           240.000000   46.873333   599.936667   45.000000   931.810000
# mid           479.999998   51.503667  1238.265667   77.249998  1847.019333
# high          704.000000   53.510000  1880.779667  114.750000  2753.039667
#
#             Var_per_order  Trans_per_order  Transp_order_with_V  \
# D_Scenario
# very_low        35.904667         4.540000             7.361667
# ...

# %%
join_HD_F = pd.concat([alb_F_HD, wue_F_HD])
F_HD = join_HD_F.groupby("Customers_N").mean()
F_HD
# Out:
#                Distance        Time       Stops  Stops_h  FixedDC_Cost  \
# Customers_N
# 25            79117.595  13623.4995   26.000000    6.925         560.0
# 50           115384.134  23028.1985   51.999996    8.185         560.0
# 100          190303.093  41260.7485  103.499996    9.055         560.0
# 150          282490.800  61500.5000  154.950000    9.115         560.0
#
#              Trans_Cost  Variable_DC     Fixed_V  Total_Cost  Var_per_order  \
# Customers_N
# 25              79.8385       99.554   22.499992    761.8925          3.983
# 50             131.6480      196.382   44.999985    933.0300          3.927
# 100            232.9245      390.104   78.749996   1261.7785          3.901
# 150            346.9735      588.197  111.375000   1606.5455          3.920
#
#              Trans_per_order  Transp_order_with_V  FixedDC_per_order  \
# Customers_N
# 25                    3.1930               4.0930              22.40
# ...

# %%
join_HD_D = pd.concat([alb_D_HD, wue_D_HD])
D_HD = join_HD_D.groupby("Customers_N").mean()
D_HD
# Out:
#                Distance        Time       Stops  Stops_h  FixedDC_Cost  \
# Customers_N
# 25            75022.100  13277.0500   26.000000    7.105         480.0
# 50           115718.025  23054.0965   51.999994    8.190         480.0
# 100          182195.991  40994.4480  103.149995    9.120         480.0
# 150          294669.050  62832.9000  154.900000    8.905         480.0
#
#              Trans_Cost  Variable_DC     Fixed_V  Total_Cost  Var_per_order  \
# Customers_N
# 25              77.4335      169.010   22.500000    748.9435          6.760
# 50             131.8355      333.392   44.999984    990.2275          6.667
# 100            230.1825      662.270   70.874995   1443.3275          6.622
# 150            355.5815      998.567  110.250000   1944.3985          6.657
#
#              Trans_per_order  Transp_order_with_V  FixedDC_per_order  \
# Customers_N
# 25                    3.0970               3.9970               19.2
# ...

# %%
join_HD_IS = pd.concat([alb_IS_HD, wue_IS_HD])
IS_HD = join_HD_IS.groupby("Customers_N").mean()
IS_HD
# Out:
#                Distance       Time       Stops  Stops_h  FixedDC_Cost  \
# Customers_N
# 25            60789.200  12435.000   26.000000    7.585         240.0
# 50            88352.694  21565.099   51.999996    8.730         240.0
# 100          143116.300  38764.650  103.000000    9.590         480.0
# 150          217311.500  57982.750  155.600000    9.680         720.0
#
#              Trans_Cost  Variable_DC     Fixed_V  Total_Cost  Var_per_order  \
# Customers_N
# 25              70.8160      307.922   22.500000    641.2380         12.318
# 50             119.7365      607.412   44.999979   1012.1485         12.148
# 100            212.4130     1206.815   67.500000   1966.7280         12.068
# 150            318.3035     1819.307  126.000000   2983.6105         12.129
#
#              Trans_per_order  Transp_order_with_V  FixedDC_per_order  \
# Customers_N
# 25                    2.8325               3.7325                9.6
# ...

# %%
plt.style.use("seaborn-ticks")

xticks = [1,2,3,4]
labels = ["$25$C","$50$C", "$100$C", "$150$C"]


fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=set_size(500), sharey=True)

fig.supxlabel("\\textbf{Demand Scenario}", y = 0.05, fontsize=12)
ax1.set_title("\\textbf{In Store}", fontsize=14)
ax2.set_title("\\textbf{Darkstore}", fontsize=14)
ax3.set_title("\\textbf{Fulfillment Centre}", fontsize=14)
ax1.set_ylabel("\\textbf{Cost/Order in €")

ax1.plot(labels, IS["FixedDC_per_order"], label="Fixed Cost")
ax1.plot(labels, IS["Trans_per_order"], label="Delivery Cost")
ax1.plot(labels, IS["Fixed_V"], label="Vehicle Cost")
ax1.plot(labels, IS["Var_per_order"], label="Variable Cost")
ax1.plot(labels, IS["Total"], color = "black", lw=2, label="Total")

ax2.plot(labels, D["FixedDC_per_order"])
ax2.plot(labels, D["Trans_per_order"])
ax2.plot(labels, D["Fixed_V"])
ax2.plot(labels, D["Var_per_order"])
ax2.plot(labels, D["Total"], color = "black", lw=2, label="Total")

ax3.plot(labels, FC["FixedDC_per_order"])
ax3.plot(labels, FC["Trans_per_order"])
ax3.plot(labels, FC["Fixed_V"])
ax3.plot(labels, FC["Var_per_order"])
ax3.plot(labels, FC["Total"], color = "black", lw=2, label="Total")

ax1.yaxis.grid(True)
ax2.yaxis.grid(True)
ax3.yaxis.grid(True)
#loc =plticker.MultipleLocator(base=2.5)
#ax1.yaxis.set_major_locator(loc)
#ax2.yaxis.set_major_locator(loc)

handles, labels = ax1.get_legend_handles_labels()
fig.legend(handles, labels, loc='lower center', frameon=False,
           fancybox=False, ncol=5, borderpad=0.1, labelspacing = 0.2, borderaxespad=0.1)


fig.tight_layout()
plt.show()
fig.savefig("result_graph/demand_scenario_cost_structure.svg", format = "svg")
